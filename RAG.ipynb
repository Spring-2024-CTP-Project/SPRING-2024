# %%
from langchain_openai import ChatOpenAI
import openai
import json
import os

# %%
from openai import OpenAI
client = OpenAI()

# JSON data
character_data = {
  "characters": [
    {
      "Name": "Dinorah",
      "Race": "Human",
      "Class": "Wizard",
      "Weapons": ["Staff", "Spellbook"],
      "Background": "Scholar"
    },
    {
      "Name": "Evan",
      "Race": "Elf",
      "Class": "Ranger",
      "Weapons": ["Longbow", "Dagger"],
      "Background": "Outlander"
    },
    {
      "Name": "Anthony",
      "Race": "Lizard",
      "Class": "Fighter",
      "Weapons": ["Battleaxe", "Shield"],
      "Background": "Soldier"
    }
  ]
}

# List to store generated character stories
character_stories = []

# Generate fantasy background stories for each character
for character in character_data["characters"]:
    message = f"Describe the background of a {character['Race']} {character['Class']} named {character['Name']}. This character's weapons are the {', '.join(character['Weapons'])}. They hail from a {character['Background']} background. Use 150 words."

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a Dungeons & Dragons expert"},
            {"role": "user", "content": message}
        ]
    )

    character_story = response.choices[0].message.content.strip()
    character_stories.append(character_story)

# Print character stories
print("Character Stories:")
for i, character_story in enumerate(character_stories):
    print(f"{i+1}. {character_data['characters'][i]['Name']}'s Story:")
    print(character_story)
    print()

    # Combine all character stories into one text
all_stories = "\n\n".join(character_stories)

# Prompt for generating a general story for the adventure
prompt = f"As the sun sets on the land of fantasy, a group of adventurers gathers for the beginning of their epic journey. Among them are {', '.join([character['Name'] for character in character_data['characters']])}. Each with their own unique background, they come together with a shared purpose: to embark on a Dungeons & Dragons campaign like no other. Here are their stories:\n\n{all_stories}\n\nNow, as they stand on the threshold of adventure, the path before them is uncertain. Write the opening scene of their quest."

# Generate the beginning of the adventure story
response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "You are a Dungeons & Dragons expert"},
        {"role": "user", "content": prompt}
    ]
)

# Extract the generated story from the response
beginning_of_adventure = response.choices[0].message.content.strip()


# List to store generated character images
character_images = []
# Generate fantasy-style images for each character
for character in character_data["characters"]:
    prompt = f"Generate a fantasy image of a {character['Race']} {character['Class']} named {character['Name']}. They are equipped with {', '.join(character['Weapons'])} and have a {character['Background']} background."

    response = client.images.generate(
        model="dall-e-3",
        prompt=prompt ,
        size="1024x1024",
        quality="hd",
        #n of imgs
        n=1,
    )

    character_image_url = response.data[0].url
    character_images.append(character_image_url)

# Print character images
print("Character Images:")
for i, character_image_url in enumerate(character_images):
    print(f"{i+1}. {character_data['characters'][i]['Name']}'s Image:")
    print(character_image_url)
    print()

# Print the beginning of the adventure story
print("Beginning of Adventure Story:")
print(beginning_of_adventure)


# Print D&D Campaign
print("D&D Campaign:")
print("Welcome adventurers to the world of magic and mystery!")
print("In this campaign, you'll embark on a journey alongside:")
for i, character in enumerate(character_data["characters"]):
    print(f"{i+1}. {character['Name']}, the {character['Race']} {character['Class']}")
    print(f"   Background: {character['Background']}")
3A34Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-04-12T12%3A05%3A44Z&ske=2024-04-13T12%3A05%3A44Z&sks=b&skv=2021-08-06&sig=buLDR5nx00VAkWMxIwV74gmAYgBP%2BQE/dDP8M0BFSQo%3D
#
# 3. Anthony's Image:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-lAX5g2uvwKgUWIaJSrME1CLK/user-xN2UrnljiWpCt7XCuZPB1ADw/img-d2BGWUdEHdQ4Hn52pgBjInGD.png?st=2024-04-12T17%3A36%3A50Z&se=2024-04-12T19%3A36%3A50Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-04-12T08%3A13%3A19Z&ske=2024-04-13T08%3A13%3A19Z&sks=b&skv=2021-08-06&sig=LhfOilS1k8w0%2B37m8DgjgX6DS2ULXmO5BODfpJm4z88%3D
#
# Beginning of Adventure Story:
# The fading light of the setting sun cast long shadows across the clearing where Dinorah, Evan, and Anthony stood, their resolve unwavering as they prepared to embark on their epic journey. A gentle breeze rustled through the trees, carrying the promise of adventure and danger on its whispering breath.
#
# Dinorah, her silver hair shimmering in the fading light, adjusted the straps of her leather satchel and tightened her grip on her intricately carved staff. The runes etched into its smooth surface hummed with latent power, responding to her touch with a faint glow. She cast a thoughtful glance towards Evan, the Elf Ranger, whose sharp eyes scanned the surrounding forest with a hunter's focus. His longbow was strung and ready, a quiver of arrows at his side, his dagger glinting in the dying light.
#
# Anthony, the imposing Lizardfolk warrior, stood tall and resolute, his battleaxe gleaming in the fading sunlight. His shield bore the scars of countless battles, a testament to his skill and strength. Despite the calm exterior he presented to his companions, a fire burned within him, fueling his determination to confront whatever challenges lay ahead.
#
# As the last rays of sunlight dipped below the horizon, casting the land into shadow, a sense of anticipation filled the air. The companions exchanged nods of silent determination, their shared purpose binding them together in a bond stronger than any words could convey.
#
# With a final glance towards the darkening forest ahead, Dinorah raised her staff, Evan notched an arrow, and Anthony tightened his grip on his battleaxe. The time had come to step onto the unknown path that awaited them, to face the trials and tribulations of their quest with courage and hope in their hearts.
#
# Together, as the first stars began to twinkle in the night sky above, Dinorah, Evan, and Anthony took their first steps into the darkness, united in their quest and ready to confront whatever challenges fate had in store for them. The stage was set for their epic adventure to unfold, the land of fantasy waiting to reveal its secrets to those brave enough to seek them.
# D&D Campaign:
# Welcome adventurers to the world of magic and mystery!
# In this campaign, you'll embark on a journey alongside:
# 1. Dinorah, the Human Wizard
#    Background: Scholar
#    Weapons: Staff, Spellbook
#
# 2. Evan, the Elf Ranger
#    Background: Outlander
#    Weapons: Longbow, Dagger
#
# 3. Anthony, the Lizard Fighter
#    Background: Soldier
#    Weapons: Battleaxe, Shield
#
# Your quest awaits! May the dice roll in your favor!

# %%
import os
import json
from langchain_openai import ChatOpenAI

# Initialize ChatOpenAI with your API key
chat = ChatOpenAI(
    openai_api_key=os.environ["OPENAI_API_KEY"],
    model='gpt-3.5-turbo'
)
